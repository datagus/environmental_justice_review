# %% [markdown]
# # SLR Data Pipeline

# %%
import pybliometrics

pybliometrics.scopus.init()

# %%
import pandas as pd
import requests
from tqdm import tqdm
from pybliometrics.scopus import ScopusSearch, AbstractRetrieval

# %% [markdown]
# ## Search Strings

# %%
search_string = """TITLE-ABS("environmental justice" OR "environmental injustice")"""

# %%
results = ScopusSearch(search_string, verbose = True, download = True)

# %%
results.get_results_size()
# Out:
# 8688

# %%
pd.set_option('display.max_columns', None)

# %%
search_df = pd.DataFrame(results.results)

# %%
search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8688 entries, 0 to 8687
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eid                  8688 non-null   object
#  1   doi                  7643 non-null   object
#  2   pii                  1254 non-null   object
#  3   pubmed_id            1069 non-null   object
#  4   title                8688 non-null   object
#  5   subtype              8688 non-null   object
#  6   subtypeDescription   8688 non-null   object
#  7   creator              8587 non-null   object
#  8   afid                 8077 non-null   object
#  9   affilname            8077 non-null   object
#  10  affiliation_city     8031 non-null   object
#  11  affiliation_country  8073 non-null   object
#  12  author_count         8587 non-null   object
#  13  author_names         8587 non-null   object
#  14  author_ids           8587 non-null   object
#  15  author_afids         8077 non-null   object
#  16  coverDate            8688 non-null   object
#  17  coverDisplayDate     8688 non-null   object
#  18  publicationName      8688 non-null   object
#  19  issn                 5834 non-null   object
#  20  source_id            8688 non-null   object
#  21  eIssn                4615 non-null   object
#  22  aggregationType      8688 non-null   object
#  23  volume               6746 non-null   object
#  24  issueIdentifier      5407 non-null   object
#  25  article_number       1402 non-null   object
#  26  pageRange            6888 non-null   object
#  27  description          7821 non-null   object
#  28  authkeywords         5359 non-null   object
#  29  citedby_count        8688 non-null   int64
#  30  openaccess           8688 non-null   int64
#  31  freetoread           2906 non-null   object
#  32  freetoreadLabel      2906 non-null   object
#  33  fund_acr             2124 non-null   object
#  34  fund_no              8688 non-null   object
#  35  fund_sponsor         2348 non-null   object
# dtypes: int64(2), object(34)
# memory usage: 2.4+ MB

# %%
eids = search_df["eid"].tolist()

# %% [markdown]
# ## Abstract Retrieval

# %% [markdown]
# The code cells below are for retrieving the articles information and filter them by type and language

# %%
articles = []
for eid in tqdm(eids):
    articles.append(AbstractRetrieval(eid, view='FULL'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 8688/8688 [45:44<00:00,  3.17it/s]

# %%
len(articles)
# Out:
# 8688

# %%
import pickle

#with open('articles_raw_list.pkl', 'wb') as file:
#    pickle.dump(articles, file)


with open('articles_raw_list.pkl', 'rb') as file:
    articles = pickle.load(file)

# %%
filtered_df = search_df.copy()

# %%
filtered_df["language"] = ""
filtered_df["type"] = ""
for i, article in enumerate(articles):
    filtered_df.loc[i,"language"] = article.language
    filtered_df.loc[i,"type"] = article.subtype
    filtered_df.loc[i,"abstract"] = article.abstract

# %%
df = filtered_df.loc[((filtered_df["type"] == "ar") | (filtered_df["type"] == "re")) 
                    & (filtered_df["language"] == "eng"),]
df = df.reset_index(drop=True)

# %%
df["year1"] = df["coverDate"].str[:4]
df["year2"] = df["coverDisplayDate"].str[:4]

# %%
df = df.loc[df["year1"] != "2025",]
df = df.reset_index(drop=True)

# %%
df.head(10)
# Out:
#                   eid                              doi                pii  \
# 0  2-s2.0-85210625076  10.1016/j.scitotenv.2024.177767  S0048969724079245
# 1  2-s2.0-85206236373     10.1016/j.envres.2024.120070  S0013935124019777
# 2  2-s2.0-85208480484    10.1016/j.jhazmat.2024.136460  S0304389424030395
# 3  2-s2.0-85190870529        10.1108/MHSI-02-2024-0025               None
# 4  2-s2.0-85210170584               10.1111/cobi.14387               None
# 5  2-s2.0-85210021948      10.1016/j.chest.2024.07.143  S0012369224048451
# 6  2-s2.0-85209814335        10.1177/20426445241274848               None
# 7  2-s2.0-85209657547    10.1016/j.jenvman.2024.123414  S0301479724034005
# 8  2-s2.0-85209650872     10.1016/j.envint.2024.109091  S0160412024006779
# 9  2-s2.0-85209402182     10.1016/j.envsci.2024.103951  S1462901124002855
#
#   pubmed_id                                              title subtype  \
# 0      None  Toxic layering and compound extremes: Per- and...      ar
# 1  39406285  Air quality and wheeze symptoms in a rural chi...      ar
# 2      None  Global air quality enhancement pathways to hea...      ar
# 3      None  Navigating the labyrinth of social exclusion: ...      re
# 4  39587020  Youth engagement in global conservation govern...      ar
# 5  39059578  Recommendations for Clinicians to Combat Envir...      re
# 6      None  Concrete cracks, wood burns: Competing narrati...      ar
# 7      None  Supporting knowledge justice through community...      ar
# 8      None  A systematic evidence map protocol for mapping...      ar
# 9      None  What is equitable urban forest governance? A s...      re
#
#   subtypeDescription             creator  \
# 0            Article     Chukwuonye G.N.
# 1            Article       Johnston J.E.
# 2            Article               Xu Y.
# 3             Review    Ahmad Izhan F.F.
# 4            Article        Sithole S.S.
# 5             Review          Patti M.A.
# 6            Article        Larasatie P.
# 7            Article  Serrano-Salomón V.
# 8            Article         Seewoo B.J.
# 9             Review             Pike K.
#
#                                                 afid  \
# 0                                           60010065
# 1                        60015481;60015183;119723570
# 2  60276981;60019499;60017060;60006356;131910455;...
# 3                                  60212344;60004351
# 4                                  60000356;60000239
# 5                60030521;60018701;60014662;60002746
# 6                                  60026956;60013402
# 7       60154476;60023908;60016338;60010307;60000221
# 8                        60031806;60026489;127365629
# 9                        60016849;60010365;130379873
#
#                                            affilname  \
# 0                          The University of Arizona
# 1  University of Washington;Keck School of Medici...
# 2  The Hong Kong University of Science and Techno...
# 3  College of Business, Universiti Utara Malaysia...
# 4  University of Cape Town;Université de Lausanne...
# 5  Boston Children's Hospital;School of Public He...
# 6  University of Arkansas at Monticello;Oregon St...
# 7  College of Engineering and Applied Science;Por...
# 8  The University of Western Australia;Royal Chil...
# 9  University of Toronto;The University of Britis...
#
#                                    affiliation_city  \
# 0                                            Tucson
# 1                       Seattle;Los Angeles;Brawley
# 2  Guangzhou;Beijing;Changsha;Guilin;Jiangmen;Wuhan
# 3                                  Sintok;Shah Alam
# 4                                Cape Town;Lausanne
# 5                 Boston;Boston;Philadelphia;Boston
# 6                              Monticello;Corvallis
# 7           Boulder;Portland;Greeley;Denver;Boulder
# 8                             Perth;Melbourne;Perth
# 9                           Toronto;Vancouver;Zeist
#
# 6  19900192130  20426453         Journal     15             2-4
# 7        23371  10958630         Journal    372            None
# 8        20912  18736750         Journal    194            None
# 9        21536  18736416         Journal    162            None
#
#   article_number  pageRange  \
# 0         177767       None
# 1         120070       None
# 2         136460       None
# 3           None  1183-1203
# 4         e14387       None
# 5           None  1309-1318
# 6           None    110-118
# 7         123414       None
# 8         109091       None
# 9         103951       None
#
#                                          description  \
# 0  Per- and polyfluoroalkyl substances (PFAS) are...
# 1  Background: In California, climate change and ...
# 2  Nowadays, air pollution has emerged as a criti...
# 3  Purpose: This study aims to provide a comprehe...
# 4  Youth are increasingly recognized for their im...
# 5  Topic Importance: Asthma is a common and compl...
# 6  Innate to the human condition are rules of thu...
# 7  In community science on air quality, low-cost ...
# 8  Background: Bisphenol A (BPA) is one of the hi...
# 9  Urban forest governance comprises the formal a...
#
#                                         authkeywords  citedby_count  \
# 0  Compound climate extremes | Long- and short-ch...              0
# 1  Air pollution | Children's respiratory health ...              0
# 2  Environmental justice | Governance strategies ...              0
# 3  Academic trends | Bibliometric analysis | Digi...              0
# 4  conservación | conservation | environmental ju...              0
# 5  asthma | children | disparities | environmenta...              0
# 6  Concrete advantage | Construction material | C...              0
# 7  Air monitoring | Air quality | Community scien...              0
# 8  Biomonitoring | Bisphenol | Exposure | Human |...              0
# 9  Decision making | Distribution | Environmental...              0
#
#    openaccess freetoread  freetoreadLabel fund_acr  \
# 0           0       None             None    NIEHS
# 1           0       None             None    NIEHS
# 2           0       None             None      MOE
# 3           0       None             None     MOHE
# 4           1        all  All Open Access     UNIL
# 5           0       None             None    NHLBI
# 6           0       None             None     None
# 7           1        all  All Open Access       CU
# 8           1       None             None      MOE
# 9           1        all  All Open Access     None
#
#                        fund_no  \
# 0                  R21ES034591
# 1                    undefined
# 2                   2023YSJS08
# 3  FRGS/1/2022/SS02/UITM/02/13
# 4                    undefined
# 5                  K01HL171354
# 6                    undefined
# 7                      1952223
# 8                    undefined
# 9                    undefined
#
#                                         fund_sponsor language type  \
# 0  National Institute of Environmental Health Sci...      eng   ar
# 1  National Institute of Environmental Health Sci...      eng   ar
# 2  Open Research Fund Program of Key Laboratory o...      eng   ar
# 3             Ministry of Higher Education, Malaysia      eng   re
# 4                             Université de Lausanne      eng   ar
# 5          National Heart, Lung, and Blood Institute      eng   re
# 6                                               None      eng   ar
# 7                             University of Colorado      eng   ar
# 8                            Ministry of Environment      eng   ar
# 9                                               None      eng   re
#
#                                             abstract year1 year2
# 0  © 2024 Elsevier B.V.Per- and polyfluoroalkyl s...  2024  20 D
# 1  © 2024Background: In California, climate chang...  2024  15 D
# 2  © 2024Nowadays, air pollution has emerged as a...  2024  5 De
# 3  © 2024, Emerald Publishing Limited.Purpose: Th...  2024  3 De
# 4  © 2024 The Author(s). Conservation Biology pub...  2024  Dece
# 5  © 2024 American College of Chest PhysiciansTop...  2024  Dece
# 6  © The Author(s) 2024.Innate to the human condi...  2024  Dece
# 7  © 2024 The AuthorsIn community science on air ...  2024  Dece
# 8  © 2024 The AuthorsBackground: Bisphenol A (BPA...  2024  Dece
# 9  © 2024Urban forest governance comprises the fo...  2024  Dece

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5920 entries, 0 to 5919
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   eid                  5920 non-null   object
#  1   doi                  5561 non-null   object
#  2   pii                  1144 non-null   object
#  3   pubmed_id            923 non-null    object
#  4   title                5920 non-null   object
#  5   subtype              5920 non-null   object
#  6   subtypeDescription   5920 non-null   object
#  7   creator              5896 non-null   object
#  8   afid                 5662 non-null   object
#  9   affilname            5662 non-null   object
#  10  affiliation_city     5645 non-null   object
#  11  affiliation_country  5661 non-null   object
#  12  author_count         5896 non-null   object
#  13  author_names         5896 non-null   object
#  14  author_ids           5896 non-null   object
#  15  author_afids         5662 non-null   object
#  16  coverDate            5920 non-null   object
#  17  coverDisplayDate     5920 non-null   object
#  18  publicationName      5920 non-null   object
#  19  issn                 4960 non-null   object
#  20  source_id            5920 non-null   object
#  21  eIssn                3917 non-null   object
#  22  aggregationType      5920 non-null   object
#  23  volume               5702 non-null   object
#  24  issueIdentifier      4723 non-null   object
#  25  article_number       1262 non-null   object
#  26  pageRange            4426 non-null   object
#  27  description          5676 non-null   object
#  28  authkeywords         4385 non-null   object
#  29  citedby_count        5920 non-null   int64
#  30  openaccess           5920 non-null   int64
#  31  freetoread           2351 non-null   object
#  32  freetoreadLabel      2351 non-null   object
#  33  fund_acr             1957 non-null   object
#  34  fund_no              5920 non-null   object
#  35  fund_sponsor         2161 non-null   object
#  36  language             5920 non-null   object
#  37  type                 5920 non-null   object
#  38  abstract             5676 non-null   object
#  39  year1                5920 non-null   object
#  40  year2                5920 non-null   object
# dtypes: int64(2), object(39)
# memory usage: 1.9+ MB

# %%
dir(articles[1])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache_file_path',
#  '_confevent',
#  '_head',
#  '_json',
#  '_mdate',
#  '_ref',
#  '_refresh',
#  '_view',
#  'abstract',
#  'affiliation',
#  'aggregationType',
#  'authkeywords',
#  'authorgroup',
#  'authors',
#  'chemicals',
#  'citedby_count',
#  'citedby_link',
#  'confcode',
#  'confdate',
#  'conflocation',
#  'confname',
#  'confsponsor',
#  'contributor_group',
#  'copyright',
#  'copyright_type',
#  'correspondence',
#  'coverDate',
#  'date_created',
#  'description',
#  'document_entitlement_status',
#  'doi',
#  'eid',
#  'endingPage',
#  'funding',
#  'funding_text',
#  'get_bibtex',
#  'get_cache_file_age',
#  'get_cache_file_mdate',
#  'get_html',
#  'get_key_remaining_quota',
#  'get_key_reset_time',
#  'get_latex',
#  'get_ris',
#  'identifier',
#  'idxterms',
#  'isbn',
#  'issn',
#  'issueIdentifier',
#  'issuetitle',
#  'language',
#  'openaccess',
#  'openaccessFlag',
#  'pageRange',
#  'pii',
#  'publicationName',
#  'publisher',
#  'publisheraddress',
#  'pubmed_id',
#  'refcount',
#  'references',
#  'scopus_link',
#  'self_link',
#  'sequencebank',
#  'source_id',
#  'sourcetitle_abbreviation',
#  'srctype',
#  'startingPage',
#  'subject_areas',
#  'subtype',
#  'subtypedescription',
#  'title',
#  'url',
#  'volume',
#  'website']
